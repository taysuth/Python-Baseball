# %%
import os
import glob
import pandas as pd

# %%
# %load \stats\data.py

# %%
game_files = glob.glob(os.path.join(os.getcwd(),'games','*.EVE'))

# %%
list.sort(game_files)

# %%
game_frames = []
for game_file in game_files:
    game_frame = pd.read_csv(game_file,names=['type','multi2','multi3','multi4','multi5','multi6','event'])
    game_frames.append(game_frame)

# %%
games = pd.concat(game_frames)

# %%
games.tail()
# Out:
#      type multi2    multi3 multi4 multi5 multi6 event
# 245  data     er  jeffj001      0    NaN    NaN   NaN
# 246  data     er  rivef001      0    NaN    NaN   NaN
# 247  data     er  hadej001      1    NaN    NaN   NaN
# 248  data     er  handb001      0    NaN    NaN   NaN
# 249  data     er  strir001      3    NaN    NaN   NaN

# %%
games.describe()
# Out:
#          type multi2 multi3 multi4 multi5 multi6 event
# count   19048  19046  18081  15408  14323   6542  9853
# unique      8   2315   2884   1247     42    977  1272
# top      play      6      0      0     ??      1    NP
# freq     9853   1402   5128   2950   6875    641  2834

# %%
games.loc[games['multi5'] == '??','multi5']= ""

# %%
games.describe()
# Out:
#          type multi2 multi3 multi4 multi5 multi6 event
# count   19048  19046  18081  15408  14323   6542  9853
# unique      8   2315   2884   1247     42    977  1272
# top      play      6      0      0             1    NP
# freq     9853   1402   5128   2950   6875    641  2834

# %%
identifiers = games['multi2'].str.extract(r'(.LS(\d{4})\d{5})')

# %%
identifiers.head()
# Out:
#               0     1
# 0  ALS193307060  1933
# 1           NaN   NaN
# 2           NaN   NaN
# 3           NaN   NaN
# 4           NaN   NaN

# %%
identifiers = identifiers.fillna(method='ffill')

# %%
identifiers.columns =['game_id','year']

# %%
identifiers.tail()
# Out:
#           game_id  year
# 245  NLS201807170  2018
# 246  NLS201807170  2018
# 247  NLS201807170  2018
# 248  NLS201807170  2018
# 249  NLS201807170  2018

# %%
games = pd.concat([games,identifiers],axis=1,sort=False)

# %%
games.head()
# Out:
#       type         multi2                       multi3 multi4 multi5 multi6  \
# 0       id   ALS193307060                          NaN    NaN    NaN    NaN
# 1  version              1                          NaN    NaN    NaN    NaN
# 2     info  inputprogvers  version 7RS(19) of 07/07/92    NaN    NaN    NaN
# 3     info        visteam                          NLS    NaN    NaN    NaN
# 4     info       hometeam                          ALS    NaN    NaN    NaN
#
#   event       game_id  year
# 0   NaN  ALS193307060  1933
# 1   NaN  ALS193307060  1933
# 2   NaN  ALS193307060  1933
# 3   NaN  ALS193307060  1933
# 4   NaN  ALS193307060  1933

# %%
games = games.fillna('')

# %%
games.head()
# Out:
#       type         multi2                       multi3 multi4 multi5 multi6  \
# 0       id   ALS193307060
# 1  version              1
# 2     info  inputprogvers  version 7RS(19) of 07/07/92
# 3     info        visteam                          NLS
# 4     info       hometeam                          ALS
#
#   event       game_id  year
# 0        ALS193307060  1933
# 1        ALS193307060  1933
# 2        ALS193307060  1933
# 3        ALS193307060  1933
# 4        ALS193307060  1933

# %%
git add . && git commit -m 'Completed module'
# Out:
#   File "<ipython-input-21-b9d8e43d99f0>", line 1
#     git add . && git commit -m 'Completed module'
#         ^
# SyntaxError: invalid syntax
